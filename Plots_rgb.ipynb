# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
X_LABEL = "Number of Pixels in Image"
X_LABEL2 = "Squared Root of Number of Pixels in Image"

# %%
df_h = pd.read_csv('data_huffman.csv')
df_h = df_h.round(4)
df_h = df_h.sort_values('image_size')

# %%
df_h
# Out:
#                image_name  image_size       cp  noobpp      ct    cm      dt  \
# 4         ./images/14.png         768  29.3945  5.6484  0.0006  1852  0.0010
# 1         ./images/11.png        3072  51.5869  3.8730  0.0010  1972  0.0030
# 2         ./images/12.png        6912  47.3976  4.2082  0.0025  1812  0.0031
# 12         ./images/9.png       12288  11.2152  7.1028  0.0019  1920  0.0071
# 3         ./images/13.png       19200  54.0918  3.6727  0.0038  3540  0.0082
# 10         ./images/7.bmp       44016   5.8206  7.5344  0.0075  3552  0.0268
# 11         ./images/8.ppm       49152  51.5584  3.8753  0.0034  3500  0.0216
# 13  ./images/colombia.jpg      196608  19.7084  6.4233  0.0196  3768  0.0702
# 9          ./images/6.bmp      203577   4.4439  7.6445  0.0206  3568  0.1162
# 8          ./images/5.bmp      407286   7.4923  7.4006  0.0356  3876  0.2136
# 7          ./images/4.bmp      551304   4.9114  7.6071  0.0535  3848  0.3395
# 0         ./images/10.ppm      786432  37.8912  4.9687  0.0573  4216  0.2931
# 6          ./images/3.bmp     1065024   3.3749  7.7300  0.1024  4516  0.6258
# 5          ./images/2.bmp     1499520   4.0409  7.6767  0.1215  4784  0.9133
#
#        dm
# 4    3288
# 1    3320
# 2    3400
# 12   3844
# 3    3360
# 10   4224
# 11   3668
# 13   5220
# 9    6120
# 8    8628
# 7   11196
# 0   10440
# 6   15904
# 5   23068

# %%
img_size = df_h.iloc[:, 1].values
cp_h = df_h.iloc[:, 2].values
nobpp_h = df_h.iloc[:, 3].values
ct_h = df_h.iloc[:, 4].values
cm_h = df_h.iloc[:, 5].values
dt_h = df_h.iloc[:, 6].values
dm_h = df_h.iloc[:, 7].values

# %%
df_ih = pd.read_csv('data_improved_huffman.csv')
df_ih = df_ih.round(4)
df_ih = df_ih.sort_values('image_size')

# %%
df_ih
# Out:
#                image_name  image_size       cp  noobpp      ct    cm      dt  \
# 4         ./images/14.png         768  25.4069  5.9675  0.0006  1900  0.0010
# 1         ./images/11.png        3072  50.6063  3.9515  0.0017  1852  0.0018
# 2         ./images/12.png        6912  47.7629  4.1790  0.0017  1816  0.0031
# 12         ./images/9.png       12288   7.9508  7.3639  0.0031  1816  0.0076
# 3         ./images/13.png       19200  54.9043  3.6077  0.0033  3424  0.0068
# 10         ./images/7.bmp       44016   6.8083  7.4553  0.0084  3468  0.0292
# 11         ./images/8.ppm       49152  55.7571  3.5394  0.0200  3556  0.0284
# 13  ./images/colombia.jpg      196608  31.0046  5.5196  0.0472  3668  0.0874
# 9          ./images/6.bmp      203577  10.5826  7.1534  0.0598  3456  0.1337
# 8          ./images/5.bmp      407286  12.0792  7.0337  0.1185  3864  0.3166
# 7          ./images/4.bmp      551304   6.3635  7.4909  0.1139  3916  0.3886
# 0         ./images/10.ppm      786432  49.5157  4.0388  0.1175  4088  0.2858
# 6          ./images/3.bmp     1065024   7.7026  7.3838  0.2115  4492  0.7147
# 5          ./images/2.bmp     1499520   4.6192  7.6305  0.2495  4832  0.9115
#
#        dm
# 4    3328
# 1    3360
# 2    3368
# 12   3668
# 3    3844
# 10   4120
# 11   3648
# 13   5148
# 9    6020
# 8    8820
# 7   11792
# 0   10772
# 6   16792
# 5   24172

# %%
img_size = df_ih.iloc[:, 1].values
cp_ih = df_ih.iloc[:, 2].values
nobpp_ih = df_ih.iloc[:, 3].values
ct_ih = df_ih.iloc[:, 4].values
cm_ih = df_ih.iloc[:, 5].values
dt_ih = df_ih.iloc[:, 6].values
dm_ih = df_ih.iloc[:, 7].values

# %%
df_a = pd.read_csv('data_arithmetic.csv')
df_a = df_a.round(4)
df_a = df_a.sort_values('image_size')

# %%
df_a
# Out:
#                image_name  image_size       cp  noobpp      ct     cm      dt  \
# 4         ./images/14.png         768  29.3620  5.6510  0.0015   1824  0.0022
# 1         ./images/11.png        3072  51.9531  3.8438  0.0038   1820  0.0036
# 2         ./images/12.png        6912  47.6816  4.1855  0.0088   3456  0.0074
# 12         ./images/9.png       12288  11.5529  7.0758  0.0290   3884  0.0229
# 3         ./images/13.png       19200  54.9277  3.6058  0.0213   3624  0.0180
# 10         ./images/7.bmp       44016   6.1691  7.5065  0.1408   4600  0.1004
# 11         ./images/8.ppm       49152  51.8728  3.8502  0.0594   4496  0.0536
# 13  ./images/colombia.jpg      196608  21.7264  6.2619  0.4753   8016  0.2905
# 9          ./images/6.bmp      203577   5.0682  7.5946  0.6090   8416  0.3922
# 8          ./images/5.bmp      407286   7.8615  7.3711  0.9198  13020  0.7210
# 7          ./images/4.bmp      551304   5.4663  7.5627  1.1989  16600  0.9394
# 0         ./images/10.ppm      786432  40.2637  4.7789  1.1393  20316  0.9766
# 6          ./images/3.bmp     1065024   3.8186  7.6945  2.3624  29300  2.0032
# 5          ./images/2.bmp     1499520   4.4444  7.6444  3.3936  39700  2.5252
#
#        dm
# 4    3404
# 1    3316
# 2    3500
# 12   3808
# 3    3756
# 10   4720
# 11   4524
# 13   8196
# 9    9092
# 8   14888
# 7   19972
# 0   22704
# 6   32704
# 5   46392

# %%
img_size = df_a.iloc[:, 1].values
cp_a = df_a.iloc[:, 2].values
nobpp_a = df_a.iloc[:, 3].values
ct_a = df_a.iloc[:, 4].values
cm_a = df_a.iloc[:, 5].values
dt_a = df_a.iloc[:, 6].values
dm_a = df_a.iloc[:, 7].values

# %%
print(df_a.columns.tolist())
# Out:
# ['image_name', 'image_size', 'cp', 'noobpp', 'ct', 'cm', 'dt', 'dm']

# %%
sqrt_img_size = np.sqrt(img_size)

# %%
# Compression Time

plt.close()
plt.plot(img_size,ct_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,ct_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,ct_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Compression Time (in seconds)")
plt.legend()
plt.savefig('./figures/ct_rgb.jpg', format = 'jpg')
plt.show()

# %%
# Decompression Time

plt.close()
plt.plot(img_size,dt_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,dt_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,dt_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Decompression Time (in seconds)")
plt.legend()
plt.savefig('./figures/dt_rgb.jpg', format = 'jpg')
plt.show()

# %%
# compression memory

plt.close()
plt.plot(img_size,cm_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,cm_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,cm_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Compression Memory (in Kbs)")
plt.legend()
plt.savefig('./figures/cm_rgb.jpg', format = 'jpg')
plt.show()

# %%
# decompression memory

plt.close()
plt.plot(img_size,dm_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,dm_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,dm_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Deompression Memory (in Kbs)")
plt.legend()
plt.savefig('./figures/dm_rgb.jpg', format = 'jpg')
plt.show()

# %%
# compression percentage

plt.close()
plt.plot(sqrt_img_size,cp_h,color='red', lw = 2,  label='Huffman')
plt.plot(sqrt_img_size,cp_a,color='green', lw = 2, label='Arithmetic')
plt.plot(sqrt_img_size,cp_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL2)
plt.ylabel("Compression Percentage")
plt.legend()
plt.savefig('./figures/cp_rgb.jpg', format = 'jpg')
plt.show()

# %%
# compression percentage

plt.close()
plt.plot(sqrt_img_size,nobpp_h,color='red', lw = 2,  label='Huffman')
plt.plot(sqrt_img_size,nobpp_a,color='green', lw = 2, label='Arithmetic')
plt.plot(sqrt_img_size,nobpp_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL2)
plt.ylabel("Number of bits per pixel")
plt.savefig('./figures/nobpp_rgb.jpg', format = 'jpg')
plt.show()

# %% [markdown]
# # BELOW CODE CHECKS THE BEHAVIOUR OF ARITHMETIC CODING WITH CODE LENGTH

# %%
df = pd.read_csv('data_chk.csv')
df = df.round(4)
df = df.sort_values('image_size')

# %%
df
# Out:
#    image_name  image_size       cp  noobpp      ct    cm image_name.1  \
# 0     chk.jpg         100  26.8750  5.8500  0.0003  1888      chk.jpg
# 1     chk.jpg         400  19.8125  6.4150  0.0005  1972      chk.jpg
# 2     chk.jpg         900  17.0833  6.6333  0.0011  1820      chk.jpg
# 3     chk.jpg        1600  16.0859  6.7131  0.0012  1904      chk.jpg
# 4     chk.jpg        2500  15.5300  6.7576  0.0017  1852      chk.jpg
# 5     chk.jpg        3600  15.0694  6.7944  0.0012  1816      chk.jpg
# 6     chk.jpg        4900  15.3597  6.7712  0.0021  1816      chk.jpg
# 7     chk.jpg        6400  15.2578  6.7794  0.0017  1972      chk.jpg
# 8     chk.jpg        8100  15.2052  6.7836  0.0030  1820      chk.jpg
# 9     chk.jpg       10000  15.1600  6.7872  0.0037  3368      chk.jpg
# 10    chk.jpg       12100  15.2851  6.7772  0.0035  3428      chk.jpg
# 11    chk.jpg       14400  14.4887  6.8409  0.0028  3528      chk.jpg
# 12    chk.jpg       16900  15.1605  6.7872  0.0035  3620      chk.jpg
# 13    chk.jpg       19600  15.1429  6.7886  0.0038  3464      chk.jpg
# 14    chk.jpg       22500  15.0067  6.7995  0.0054  3552      chk.jpg
# 15    chk.jpg       25600  14.9575  6.8034  0.0045  3560      chk.jpg
# 16    chk.jpg       28900  15.1933  6.7845  0.0046  3452      chk.jpg
# 94    chk.jpg      902500  15.4641  6.7629  0.1315  4212      chk.jpg
# 95    chk.jpg      921600  15.3763  6.7699  0.1230  4384      chk.jpg
# 96    chk.jpg      940900  15.4669  6.7626  0.1404  4432      chk.jpg
# 97    chk.jpg      960400  15.4717  6.7623  0.1352  4424      chk.jpg
# 98    chk.jpg      980100  15.4647  6.7628  0.1231  4336      chk.jpg
# 99    chk.jpg     1000000  15.4429  6.7646  0.1334  4468      chk.jpg
#
#     image_size.1     cp.1  noobpp.1    ct.1   cm.1  dt  dm
# 0            100  24.6250    6.0300  0.0003   1908 NaN NaN
# 1            400  20.3750    6.3700  0.0011   1904 NaN NaN
# 2            900  18.0694    6.5544  0.0034   1824 NaN NaN
# 3           1600  17.6797    6.5856  0.0046   1812 NaN NaN
# 4           2500  17.4050    6.6076  0.0051   3516 NaN NaN
# 5           3600  16.8924    6.6486  0.0103   3620 NaN NaN
# 6           4900  17.3112    6.6151  0.0120   3488 NaN NaN
# 7           6400  17.1953    6.6244  0.0193   3552 NaN NaN
# 8           8100  17.2083    6.6233  0.0178   3600 NaN NaN
# 9          10000  17.1000    6.6320  0.0204   3776 NaN NaN
# 10         12100  17.1694    6.6264  0.0260   3776 NaN NaN
# 11         14400  16.4974    6.6802  0.0322   3880 NaN NaN
# 12         16900  17.2352    6.6212  0.0350   3888 NaN NaN
# 13         19600  17.2092    6.6233  0.0422   4168 NaN NaN
# 14         22500  17.0106    6.6392  0.0487   4204 NaN NaN
# 15         25600  17.0020    6.6398  0.0544   4268 NaN NaN
# 16         28900  17.2794    6.6176  0.0606   4328 NaN NaN
# 17         32400  17.1867    6.6251  0.0677   4424 NaN NaN
# 18         36100  17.2185    6.6225  0.0907   4436 NaN NaN
# 19         40000  17.0153    6.6388  0.0814   4540 NaN NaN
# 20         44100  17.2642    6.6189  0.0899   4740 NaN NaN
# 21         48400  17.3246    6.6140  0.1221   4704 NaN NaN
# 22         52900  17.3032    6.6158  0.1850   4840 NaN NaN
# 23         57600  17.2157    6.6227  0.1233   4860 NaN NaN
# 24         62500  17.3778    6.6098  0.3794   4964 NaN NaN
# 25         67600  17.3247    6.6140  0.1403   5104 NaN NaN
# 26         72900  17.3803    6.6096  0.1636   5320 NaN NaN
# 27         78400  17.3489    6.6121  0.1776   5484 NaN NaN
# 28         84100  17.4227    6.6062  0.2193   5676 NaN NaN
# 29         90000  17.0636    6.6349  0.2240   5684 NaN NaN
# ..           ...      ...       ...     ...    ...  ..  ..
# 70        504100  17.6285    6.5897  1.0068  16040 NaN NaN
# 71        518400  17.5526    6.5958  1.2230  16276 NaN NaN
# 72        532900  17.6151    6.5908  1.2099  15764 NaN NaN
# 73        547600  17.6261    6.5899  1.0920  17096 NaN NaN
# 74        562500  17.5846    6.5932  1.1278  17240 NaN NaN
# 75        577600  17.6201    6.5904  1.1724  17496 NaN NaN
# 76        592900  17.6223    6.5902  1.3707  18016 NaN NaN
# 77        608400  17.6047    6.5916  1.2124  18340 NaN NaN
# 78        624100  17.6360    6.5891  1.2416  18680 NaN NaN
# 79        640000  17.5290    6.5977  1.4907  19132 NaN NaN
# 80        656100  17.6235    6.5901  1.3400  19452 NaN NaN
# 81        672400  17.6290    6.5897  1.6238  19724 NaN NaN
# 82        688900  17.6251    6.5900  1.4393  20260 NaN NaN
# 83        705600  17.6122    6.5910  1.4002  20596 NaN NaN
# 84        722500  17.6204    6.5904  1.4962  21132 NaN NaN
# 85        739600  17.6305    6.5896  1.4784  21400 NaN NaN
# 86        756900  17.6395    6.5888  1.8521  21600 NaN NaN
# 87        774400  17.6399    6.5888  1.5436  22144 NaN NaN
# 88        792100  17.6484    6.5881  1.6373  22452 NaN NaN
# 89        810000  17.5843    6.5933  1.6842  23108 NaN NaN
# 90        828100  17.6448    6.5884  1.6470  23192 NaN NaN
# 91        846400  17.6407    6.5887  1.8716  23876 NaN NaN
# 92        864900  17.6416    6.5887  1.9422  24188 NaN NaN
# 93        883600  17.6456    6.5884  1.8763  24852 NaN NaN
# 94        902500  17.6442    6.5885  1.9144  25176 NaN NaN
# 95        921600  17.5350    6.5972  2.1869  25492 NaN NaN
# 96        940900  17.6541    6.5877  2.1099  26076 NaN NaN
# 97        960400  17.6611    6.5871  1.9067  25464 NaN NaN
# 98        980100  17.6473    6.5882  2.1446  26064 NaN NaN
# 99       1000000  17.6194    6.5904  1.9651  26384 NaN NaN
#
# [100 rows x 14 columns]

# %%
x = df.iloc[:, 1].values
x1 = df.iloc[:, 3].values
y1 = df.iloc[:, 4].values
y2 = df.iloc[:, 10].values
x2 = df.iloc[:, 9].values
x1, x2
# Out:
# (array([5.85  , 6.415 , 6.6333, 6.7131, 6.7576, 6.7944, 6.7712, 6.7794,
#         6.7836, 6.7872, 6.7772, 6.8409, 6.7872, 6.7886, 6.7995, 6.8034,
#         6.7845, 6.7902, 6.7857, 6.7974, 6.7864, 6.7827, 6.7795, 6.7874,
#         6.7767, 6.7817, 6.7788, 6.7815, 6.7751, 6.8019, 6.7784, 6.7869,
#         6.7758, 6.7747, 6.7743, 6.781 , 6.7732, 6.7721, 6.7725, 6.7603,
#         6.7682, 6.7717, 6.7697, 6.7719, 6.7751, 6.7695, 6.7691, 6.785 ,
#         6.7687, 6.7698, 6.7688, 6.7682, 6.768 , 6.7688, 6.7673, 6.7687,
#         6.7675, 6.7662, 6.7645, 6.7862, 6.7659, 6.7647, 6.7656, 6.7529,
#         6.7644, 6.766 , 6.7645, 6.7642, 6.7653, 6.7667, 6.7629, 6.7678,
#         6.7644, 6.7634, 6.7657, 6.7642, 6.7636, 6.765 , 6.763 , 6.7706,
#         6.7635, 6.7632, 6.7631, 6.7648, 6.764 , 6.7628, 6.7631, 6.7634,
#         6.7625, 6.7666, 6.7627, 6.7628, 6.7634, 6.7627, 6.7629, 6.7699,
#         6.7626, 6.7623, 6.7628, 6.7646]),
#         4.43753235e+06, 4.54757568e+06, 4.65909959e+06, 4.77324288e+06,
#         4.88699000e+06, 5.00176688e+06, 5.11899039e+06, 5.23757696e+06,
#         5.35657625e+06, 5.48094600e+06, 5.60019187e+06, 5.72403392e+06,
#         5.84966466e+06, 5.97552172e+06, 6.10351725e+06, 6.23913984e+06,
#         6.36293034e+06, 6.49451292e+06, 6.62822028e+06, 6.76460000e+06]),
#  array([6.03000000e+02, 2.54800000e+03, 5.89896000e+03, 1.05369600e+04,
#         1.65190000e+04, 2.39349600e+04, 3.24139900e+04, 4.23961600e+04,
#         5.36487300e+04, 6.63200000e+04, 8.01794400e+04, 9.61948800e+04,
#         1.11898280e+05, 1.29816680e+05, 1.49382000e+05, 1.69978880e+05,
#         1.91248640e+05, 2.14653240e+05, 2.39072250e+05, 2.65552000e+05,
#         2.91893490e+05, 3.20117600e+05, 3.49975820e+05, 3.81467520e+05,
#         4.13112500e+05, 4.47106400e+05, 4.81839840e+05, 5.18388640e+05,
#         5.55581420e+05, 5.97141000e+05, 6.35105680e+05, 6.77672960e+05,
#         7.19469630e+05, 7.63584240e+05, 8.09259500e+05, 8.57148480e+05,
#         9.04087600e+05, 9.53112200e+05, 1.00425546e+06, 1.05459200e+06,
#         1.10902294e+06, 1.16473392e+06, 1.22046943e+06, 1.27799232e+06,
#         1.33769475e+06, 1.39636956e+06, 1.45763074e+06, 1.52469504e+06,
#         1.58405975e+06, 1.64962500e+06, 1.71606177e+06, 1.78393696e+06,
#         1.85301303e+06, 1.92339360e+06, 1.99550175e+06, 2.06875648e+06,
#         2.14271550e+06, 2.21842344e+06, 2.29477963e+06, 2.38194000e+06,
#         2.45366461e+06, 2.53392636e+06, 2.61703953e+06, 2.69508608e+06,
#         2.78516225e+06, 2.87260776e+06, 2.95865501e+06, 3.04758592e+06,
#         3.13859403e+06, 3.23096200e+06, 3.32186777e+06, 3.41926272e+06,
#         3.51223732e+06, 3.60862924e+06, 3.70867500e+06, 3.80661504e+06,
#         3.90732958e+06, 4.01032944e+06, 4.11225731e+06, 4.22252800e+06,
#         4.32376461e+06, 4.43091428e+06, 4.53985100e+06, 4.65060960e+06,
#         4.76156400e+06, 4.87366816e+06, 4.98706272e+06, 5.10236672e+06,
#         5.21843401e+06, 5.34057300e+06, 5.45585404e+06, 5.57667568e+06,
#         5.69856663e+06, 5.82151024e+06, 5.94612125e+06, 6.07997952e+06,
#         6.19836693e+06, 6.32625084e+06, 6.45709482e+06, 6.59040000e+06]))

# %%
plt.close()
# plt.plot(y1, cl1,color='red', lw = 2,  label='Huffman')
plt.plot(cl2, y2,color='green', lw = 2, label='Arithmetic')
plt.ylabel("Time (in seconds)")
plt.xlabel("Code Length")
# plt.legend()
plt.savefig('./figures/chk.jpg', format = 'jpg', dpi = 500)
plt.show()

# %%
mean_slope = np.mean(y2/cl2)
mean_slope
# Out:
# 3.418562837653215e-07
