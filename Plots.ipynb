# %%
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
X_LABEL = "Number of Pixels in Image"
X_LABEL2 = "Squared Root of Number of Pixels in Image"
R = 4

# %%
df_h = pd.read_csv('data_huffman.csv')
df_h = df_h.round(R)
df_h = df_h.sort_values('image_size')

# %%
df_h
# Out:
#                image_name  image_size       cp  noobpp      ct    cm      dt  \
# 4         ./images/14.png         256  32.1289  5.4297  0.0160  1940  0.0007
# 1         ./images/11.png        1024  56.2012  3.5039  0.0112  1896  0.0010
# 2         ./images/12.png        2304  52.3655  3.8108  0.0759  1896  0.0017
# 12         ./images/9.png        4096  13.8580  6.8914  0.0160  1896  0.0027
# 3         ./images/13.png        6400  57.7969  3.3762  0.0537  3392  0.0026
# 10         ./images/7.bmp       14672   7.2144  7.4228  0.0110  3352  0.0091
# 11         ./images/8.ppm       16384  36.6867  5.0651  0.0126  3480  0.0074
# 13  ./images/colombia.jpg       65536  22.4810  6.2015  0.0096  3928  0.0228
# 9          ./images/6.bmp       67859   7.4638  7.4029  0.2861  4320  0.0372
# 8          ./images/5.bmp      135762  14.3308  6.8535  0.0763  4956  0.0706
# 7          ./images/4.bmp      183768   6.3920  7.4886  0.0445  5132  0.1037
# 0         ./images/10.ppm      262144  31.4432  5.4845  0.0473  5960  0.1354
# 6          ./images/3.bmp      355008   4.6612  7.6271  0.0771  8420  0.2165
# 5          ./images/2.bmp      499840   7.1727  7.4262  0.0887  9740  0.3251
#
#        dm
# 4    3256
# 1    3160
# 2    3268
# 12   3472
# 3    3388
# 10   3588
# 11   3508
# 13   4004
# 9    4024
# 8    5468
# 7    6304
# 0    6544
# 6    8516
# 5   11760

# %%
img_size = df_h.iloc[:, 1].values
cp_h = df_h.iloc[:, 2].values
nobpp_h = df_h.iloc[:, 3].values
ct_h = df_h.iloc[:, 4].values
cm_h = df_h.iloc[:, 5].values
dt_h = df_h.iloc[:, 6].values
dm_h = df_h.iloc[:, 7].values

# %%
df_ih = pd.read_csv('data_improved_huffman.csv')
df_ih = df_ih.round(R)
df_ih = df_ih.sort_values('image_size')

# %%
df_ih
# Out:
#                image_name  image_size       cp  noobpp      ct    cm      dt  \
# 4         ./images/14.png         256  28.0273  5.7578  0.0004  1940  0.0010
# 1         ./images/11.png        1024  55.8105  3.5352  0.0006  1792  0.0015
# 2         ./images/12.png        2304  52.6584  3.7873  0.0010  1816  0.0022
# 12         ./images/9.png        4096  11.2305  7.1016  0.0023  3508  0.0041
# 3         ./images/13.png        6400  58.2227  3.3422  0.0020  3304  0.0027
# 10         ./images/7.bmp       14672   7.0781  7.4338  0.0047  3324  0.0107
# 11         ./images/8.ppm       16384  35.8299  5.1336  0.0058  3332  0.0084
# 13  ./images/colombia.jpg       65536  31.7202  5.4624  0.0196  3980  0.0255
# 9          ./images/6.bmp       67859  13.3136  6.9349  0.0207  3996  0.0423
# 8          ./images/5.bmp      135762  18.3286  6.5337  0.0460  4704  0.0840
# 7          ./images/4.bmp      183768   6.1155  7.5108  0.0595  4928  0.1235
# 0         ./images/10.ppm      262144  38.6838  4.9053  0.0564  5864  0.1182
# 6          ./images/3.bmp      355008   9.2226  7.2622  0.0978  8076  0.2228
# 5          ./images/2.bmp      499840   7.7695  7.3784  0.1401  9232  0.3377
#
#        dm
# 4    3248
# 1    3308
# 2    3184
# 12   3372
# 3    3348
# 10   3560
# 11   3752
# 13   3736
# 9    4396
# 8    5468
# 7    6560
# 0    6624
# 6    8868
# 5   12232

# %%
img_size = df_ih.iloc[:, 1].values
cp_ih = df_ih.iloc[:, 2].values
nobpp_ih = df_ih.iloc[:, 3].values
ct_ih = df_ih.iloc[:, 4].values
cm_ih = df_ih.iloc[:, 5].values
dt_ih = df_ih.iloc[:, 6].values
dm_ih = df_ih.iloc[:, 7].values

# %%
df_a = pd.read_csv('data_arithmetic.csv')
df_a = df_a.round(R)
df_a = df_a.sort_values('image_size')

# %%
df_a
# Out:
#                image_name  image_size       cp  noobpp      ct     cm      dt  \
# 4         ./images/14.png         256  30.6152  5.5508  0.0190   1808  0.0008
# 1         ./images/11.png        1024  56.2378  3.5010  0.0116   1808  0.0014
# 2         ./images/12.png        2304  52.4631  3.8030  0.0035   1868  0.0030
# 12         ./images/9.png        4096  14.1724  6.8662  0.4371   3516  0.0078
# 3         ./images/13.png        6400  58.5352  3.3172  0.0292   3428  0.0061
# 10         ./images/7.bmp       14672   7.4479  7.4042  0.2482   3924  0.0279
# 11         ./images/8.ppm       16384  37.2231  5.0222  0.1399   3900  0.0213
# 13  ./images/colombia.jpg       65536  23.8005  6.0960  0.2272   5024  0.0901
# 9          ./images/6.bmp       67859   7.7690  7.3785  0.1765   5368  0.1170
# 8          ./images/5.bmp      135762  14.7068  6.8235  0.3231   7004  0.2558
# 7          ./images/4.bmp      183768   6.9283  7.4457  0.4085   7836  0.3134
# 0         ./images/10.ppm      262144  33.8545  5.2916  0.4330  10016  0.3514
# 6          ./images/3.bmp      355008   5.1478  7.5882  0.8466  13756  0.6849
# 5          ./images/2.bmp      499840   7.7025  7.3838  1.1505  17168  0.8341
#
#        dm
# 4    3420
# 1    3344
# 2    3264
# 12   3500
# 3    3448
# 10   3792
# 11   3852
# 13   4876
# 9    5188
# 8    7588
# 7    9100
# 0   10760
# 6   14220
# 5   19688

# %%
img_size = df_a.iloc[:, 1].values
cp_a = df_a.iloc[:, 2].values
nobpp_a = df_a.iloc[:, 3].values
ct_a = df_a.iloc[:, 4].values
cm_a = df_a.iloc[:, 5].values
dt_a = df_a.iloc[:, 6].values
dm_a = df_a.iloc[:, 7].values

# %%
print(df_a.columns.tolist())
# Out:
# ['image_name', 'image_size', 'cp', 'noobpp', 'ct', 'cm', 'dt', 'dm']

# %%
sqrt_img_size = np.sqrt(img_size)

# %%
# Compression Time

plt.close()
plt.plot(img_size,ct_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,ct_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,ct_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Compression Time (in seconds)")
plt.legend()
plt.savefig('./figures/ct.jpg', format = 'jpg')
plt.show()

# %%
# Decompression Time

plt.close()
plt.plot(img_size,dt_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,dt_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,dt_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Decompression Time (in seconds)")
plt.legend()
plt.savefig('./figures/dt.jpg', format = 'jpg')
plt.show()

# %%
# compression memory

plt.close()
plt.plot(img_size,cm_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,cm_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,cm_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Compression Memory (in Kbs)")
plt.legend()
plt.savefig('./figures/cm.jpg', format = 'jpg')
plt.show()

# %%
# decompression memory

plt.close()
plt.plot(img_size,dm_h,color='red', lw = 2,  label='Huffman')
plt.plot(img_size,dm_a,color='green', lw = 2, label='Arithmetic')
plt.plot(img_size,dm_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL)
plt.ylabel("Deompression Memory (in Kbs)")
plt.legend()
plt.savefig('./figures/dm.jpg', format = 'jpg')
plt.show()

# %%
# compression percentage

plt.close()
plt.plot(sqrt_img_size,cp_h,color='red', lw = 2,  label='Huffman')
plt.plot(sqrt_img_size,cp_a,color='green', lw = 2, label='Arithmetic')
plt.plot(sqrt_img_size,cp_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL2)
plt.ylabel("Compression Percentage")
plt.legend()
plt.savefig('./figures/cp.jpg', format = 'jpg')
plt.show()

# %%
# compression percentage

plt.close()
plt.plot(sqrt_img_size,nobpp_h,color='red', lw = 2,  label='Huffman')
plt.plot(sqrt_img_size,nobpp_a,color='green', lw = 2, label='Arithmetic')
plt.plot(sqrt_img_size,nobpp_ih,color='blue', lw = 2, label='Improved Huffman')
plt.xlabel(X_LABEL2)
plt.ylabel("Number of bits per pixel")
plt.legend()
plt.savefig('./figures/nobpp.jpg', format = 'jpg')
plt.show()

# %%
for i in range(0, 14):
    print("\multicolumn{1}{c|}{%s} & \multicolumn{1}{c|}{%s} & \multicolumn{1}{c}{%s} & \multicolumn{1}{c|}{%s} & \multicolumn{1}{c}{%s} & \multicolumn{1}{c|}{%s} & \multicolumn{1}{c}{%s} & \multicolumn{1}{c}{%s} \\\\" % (i+1, img_size[i] ,cm_h[i], dm_h[i],cm_a[i], dm_a[i],cm_ih[i], dm_ih[i],))
# Out:
# \multicolumn{1}{c|}{1} & \multicolumn{1}{c|}{256} & \multicolumn{1}{c}{1940} & \multicolumn{1}{c|}{3256} & \multicolumn{1}{c}{1808} & \multicolumn{1}{c|}{3420} & \multicolumn{1}{c}{1940} & \multicolumn{1}{c}{3248} \\
# \multicolumn{1}{c|}{2} & \multicolumn{1}{c|}{1024} & \multicolumn{1}{c}{1896} & \multicolumn{1}{c|}{3160} & \multicolumn{1}{c}{1808} & \multicolumn{1}{c|}{3344} & \multicolumn{1}{c}{1792} & \multicolumn{1}{c}{3308} \\
# \multicolumn{1}{c|}{3} & \multicolumn{1}{c|}{2304} & \multicolumn{1}{c}{1896} & \multicolumn{1}{c|}{3268} & \multicolumn{1}{c}{1868} & \multicolumn{1}{c|}{3264} & \multicolumn{1}{c}{1816} & \multicolumn{1}{c}{3184} \\
# \multicolumn{1}{c|}{4} & \multicolumn{1}{c|}{4096} & \multicolumn{1}{c}{1896} & \multicolumn{1}{c|}{3472} & \multicolumn{1}{c}{3516} & \multicolumn{1}{c|}{3500} & \multicolumn{1}{c}{3508} & \multicolumn{1}{c}{3372} \\
# \multicolumn{1}{c|}{5} & \multicolumn{1}{c|}{6400} & \multicolumn{1}{c}{3392} & \multicolumn{1}{c|}{3388} & \multicolumn{1}{c}{3428} & \multicolumn{1}{c|}{3448} & \multicolumn{1}{c}{3304} & \multicolumn{1}{c}{3348} \\
# \multicolumn{1}{c|}{6} & \multicolumn{1}{c|}{14672} & \multicolumn{1}{c}{3352} & \multicolumn{1}{c|}{3588} & \multicolumn{1}{c}{3924} & \multicolumn{1}{c|}{3792} & \multicolumn{1}{c}{3324} & \multicolumn{1}{c}{3560} \\
# \multicolumn{1}{c|}{7} & \multicolumn{1}{c|}{16384} & \multicolumn{1}{c}{3480} & \multicolumn{1}{c|}{3508} & \multicolumn{1}{c}{3900} & \multicolumn{1}{c|}{3852} & \multicolumn{1}{c}{3332} & \multicolumn{1}{c}{3752} \\
# \multicolumn{1}{c|}{8} & \multicolumn{1}{c|}{65536} & \multicolumn{1}{c}{3928} & \multicolumn{1}{c|}{4004} & \multicolumn{1}{c}{5024} & \multicolumn{1}{c|}{4876} & \multicolumn{1}{c}{3980} & \multicolumn{1}{c}{3736} \\
# \multicolumn{1}{c|}{9} & \multicolumn{1}{c|}{67859} & \multicolumn{1}{c}{4320} & \multicolumn{1}{c|}{4024} & \multicolumn{1}{c}{5368} & \multicolumn{1}{c|}{5188} & \multicolumn{1}{c}{3996} & \multicolumn{1}{c}{4396} \\
# \multicolumn{1}{c|}{10} & \multicolumn{1}{c|}{135762} & \multicolumn{1}{c}{4956} & \multicolumn{1}{c|}{5468} & \multicolumn{1}{c}{7004} & \multicolumn{1}{c|}{7588} & \multicolumn{1}{c}{4704} & \multicolumn{1}{c}{5468} \\
# \multicolumn{1}{c|}{11} & \multicolumn{1}{c|}{183768} & \multicolumn{1}{c}{5132} & \multicolumn{1}{c|}{6304} & \multicolumn{1}{c}{7836} & \multicolumn{1}{c|}{9100} & \multicolumn{1}{c}{4928} & \multicolumn{1}{c}{6560} \\
# \multicolumn{1}{c|}{12} & \multicolumn{1}{c|}{262144} & \multicolumn{1}{c}{5960} & \multicolumn{1}{c|}{6544} & \multicolumn{1}{c}{10016} & \multicolumn{1}{c|}{10760} & \multicolumn{1}{c}{5864} & \multicolumn{1}{c}{6624} \\
# \multicolumn{1}{c|}{13} & \multicolumn{1}{c|}{355008} & \multicolumn{1}{c}{8420} & \multicolumn{1}{c|}{8516} & \multicolumn{1}{c}{13756} & \multicolumn{1}{c|}{14220} & \multicolumn{1}{c}{8076} & \multicolumn{1}{c}{8868} \\
# \multicolumn{1}{c|}{14} & \multicolumn{1}{c|}{499840} & \multicolumn{1}{c}{9740} & \multicolumn{1}{c|}{11760} & \multicolumn{1}{c}{17168} & \multicolumn{1}{c|}{19688} & \multicolumn{1}{c}{9232} & \multicolumn{1}{c}{12232} \\
